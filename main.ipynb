# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import count as pyspark_count,count, when, isnan, sum,coalesce,col, concat_ws
import os

# %%
spark = SparkSession.builder \
    .appName("Traffic Data Transformation") \
    .config("spark.hadoop.fs.defaultFS", "file:///") \
    .config("spark.sql.warehouse.dir", os.getcwd()) \
    .getOrCreate()

# %%
data_path='Automated_Traffic_Volume_Counts_20241218.csv'
data_df=spark.read.option('header','true').csv(data_path)

# %%
data_df.printSchema()
# Out:
# root
#  |-- RequestID: string (nullable = true)
#  |-- Boro: string (nullable = true)
#  |-- Yr: string (nullable = true)
#  |-- M: string (nullable = true)
#  |-- D: string (nullable = true)
#  |-- HH: string (nullable = true)
#  |-- MM: string (nullable = true)
#  |-- Vol: string (nullable = true)
#  |-- SegmentID: string (nullable = true)
#  |-- WktGeom: string (nullable = true)
#  |-- street: string (nullable = true)
#  |-- fromSt: string (nullable = true)
#  |-- toSt: string (nullable = true)
#  |-- Direction: string (nullable = true)

# %%
data_df.show(5)
# Out:
# +---------+------+----+---+---+---+---+---+---------+--------------------+--------------+--------------------+--------+---------+
# |RequestID|  Boro|  Yr|  M|  D| HH| MM|Vol|SegmentID|             WktGeom|        street|              fromSt|    toSt|Direction|
# +---------+------+----+---+---+---+---+---+---------+--------------------+--------------+--------------------+--------+---------+
# |    32970|Queens|2021|  4| 30|  2|  0|  0|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|
# |    32970|Queens|2021|  4| 30|  2| 15|  1|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|
# |    32970|Queens|2021|  4| 30|  2| 30|  0|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|
# |    32970|Queens|2021|  4| 30|  2| 45|  0|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|
# |    32970|Queens|2021|  4| 30|  3|  0|  1|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|
# +---------+------+----+---+---+---+---+---+---------+--------------------+--------------+--------------------+--------+---------+
# only showing top 5 rows

# %%
data_count=data_df.count()
print('Total Records:',data_count)
# Out:
# Total Records: 1712605

# %%
data_df=data_df.withColumn('Date',concat_ws('-',col('Yr'),col('M'),col('D')))

# %%
data_df=data_df.withColumn('Time',concat_ws(':',col("HH"),col("MM")))

# %%
data_df = data_df.drop("Yr", "M", "D", "HH", "MM",'Data')

# %%
data_df.show(5)
# Out:
# +---------+------+---+---------+--------------------+--------------+--------------------+--------+---------+---------+----+
# |RequestID|  Boro|Vol|SegmentID|             WktGeom|        street|              fromSt|    toSt|Direction|     Date|Time|
# +---------+------+---+---------+--------------------+--------------+--------------------+--------+---------+---------+----+
# |    32970|Queens|  0|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|2021-4-30| 2:0|
# |    32970|Queens|  1|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|2021-4-30|2:15|
# |    32970|Queens|  0|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|2021-4-30|2:30|
# |    32970|Queens|  0|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|2021-4-30|2:45|
# |    32970|Queens|  1|   149701|POINT (997407.099...|PULASKI BRIDGE|Newtown Creek Sho...|Dead end|       NB|2021-4-30| 3:0|
# +---------+------+---+---------+--------------------+--------------+--------------------+--------+---------+---------+----+
# only showing top 5 rows

# %%
data_df=data_df.orderBy(col("Date").desc())

# %%
data_df.show(10)
# Out:
# +---------+--------+---+---------+--------------------+------------------+---------------+--------------------+---------+--------+-----+
# |RequestID|    Boro|Vol|SegmentID|             WktGeom|            street|         fromSt|                toSt|Direction|    Date| Time|
# +---------+--------+---+---------+--------------------+------------------+---------------+--------------------+---------+--------+-----+
# |    37697|Brooklyn|215|    28962|POINT (990590.819...|   FLATBUSH AVENUE|Atlantic Avenue|Eastern Parkway Line|       SB|2024-6-9|11:15|
# |    37697|Brooklyn|199|    28962|POINT (990590.819...|   FLATBUSH AVENUE|Atlantic Avenue|Eastern Parkway Line|       NB|2024-6-9|  0:0|
# |    37699|  Queens|126|    75814|POINT (1012773.57...|NORTHERN BOULEVARD|      69 Street|           70 Street|       EB|2024-6-9|  0:0|
# |    37697|Brooklyn|108|    28962|POINT (990590.819...|   FLATBUSH AVENUE|Atlantic Avenue|Eastern Parkway Line|       NB|2024-6-9| 2:30|
# |    37697|Brooklyn|240|    28962|POINT (990590.819...|   FLATBUSH AVENUE|Atlantic Avenue|Eastern Parkway Line|       SB|2024-6-9|13:45|
# |    37697|Brooklyn|218|    28962|POINT (990590.819...|   FLATBUSH AVENUE|Atlantic Avenue|Eastern Parkway Line|       NB|2024-6-9| 0:15|
# |    37699|  Queens| 59|    75814|POINT (1012773.57...|NORTHERN BOULEVARD|      69 Street|           70 Street|       EB|2024-6-9| 2:30|
# |    37697|Brooklyn|197|    28962|POINT (990590.819...|   FLATBUSH AVENUE|Atlantic Avenue|Eastern Parkway Line|       NB|2024-6-9| 0:30|
# |    37697|Brooklyn|238|    28962|POINT (990590.819...|   FLATBUSH AVENUE|Atlantic Avenue|Eastern Parkway Line|       SB|2024-6-9|11:30|
# |    37697|Brooklyn|185|    28962|POINT (990590.819...|   FLATBUSH AVENUE|Atlantic Avenue|Eastern Parkway Line|       NB|2024-6-9| 0:45|
# +---------+--------+---+---------+--------------------+------------------+---------------+--------------------+---------+--------+-----+
# only showing top 10 rows

# %%
null_counts = data_df.select([pyspark_count(when(col(c).isNull() | isnan(c), c)).alias(c) for c in data_df.columns])

# %%
null_counts.show()
# Out:
# +---------+----+---+---------+-------+------+------+----+---------+----+----+
# |RequestID|Boro|Vol|SegmentID|WktGeom|street|fromSt|toSt|Direction|Date|Time|
# +---------+----+---+---------+-------+------+------+----+---------+----+----+
# |        0|   0|  0|        0|      0|     0|     0|1246|        0|   0|   0|
# +---------+----+---+---------+-------+------+------+----+---------+----+----+

# %%
data_df=data_df.filter(col("toSt").isNotNull())

# %%
traffic_by_street=data_df.groupBy

# %%
popular_routes=data_df.groupby('fromSt','toSt').agg(count("*").alias('Route_frequency'),sum('Vol').alias("Total_Volume")).orderBy(col('Route_frequency')).orderBy("Route_frequency",ascending=False)

# %%
popular_routes.show(10)
# Out:
# +--------------------+--------------------+---------------+------------+
# |              fromSt|                toSt|Route_frequency|Total_Volume|
# +--------------------+--------------------+---------------+------------+
# |            Dead End|            Dead end|          71389| 1.3382925E7|
# |    BOROUGH BOUNDARY|       BODY OF WATER|          17593|   5107796.0|
# |           45 Avenue|           46 Avenue|          11317|    567782.0|
# |Harlem River Shor...|Harlem River Shor...|          10677|   2142447.0|
# |            Dead End|Bronx River Shore...|           9054|   1274906.0|
# |      West 60 Street|      West 61 Street|           8526|    927837.0|
# |       Borden Avenue|            Dead end|           8224|    587137.0|
# |Newtown Creek Sho...|            Dead end|           7980|   2141862.0|
# |       Flushing Line|       Flushing Line|           7812|    799714.0|
# |            Dead End|Harlem River Shor...|           6822|   2260627.0|
# +--------------------+--------------------+---------------+------------+
# only showing top 10 rows

# %%
departure_trends=data_df.groupBy("fromSt").agg(
    count("*").alias("Total_departures"),
    sum("Vol").alias("Total_Volume")
).orderBy("Total_departures",ascending=False)

departure_trends.show(10)
# Out:
# +--------------------+----------------+------------+
# |              fromSt|Total_departures|Total_Volume|
# +--------------------+----------------+------------+
# |            Dead End|          195077| 3.3134959E7|
# |            Dead end|           24043|   2285230.0|
# |    BOROUGH BOUNDARY|           17751|   5151806.0|
# |           45 Avenue|           11911|    586064.0|
# |Harlem River Shor...|           10677|   2142447.0|
# |       Borden Avenue|            9376|    743295.0|
# |      West 60 Street|            8526|    927837.0|
# |       Flushing Line|            8096|    815804.0|
# |Newtown Creek Sho...|            7980|   2141862.0|
# |               Alley|            7548|    244611.0|
# +--------------------+----------------+------------+
# only showing top 10 rows

# %%
destination_trends=data_df.groupBy("toSt").agg(
    count("*").alias("Total_arrivals"),
    sum("Vol").alias("Total_Volume")
).orderBy("Total_arrivals",ascending=False)

destination_trends.show(10)
# Out:
# +--------------------+--------------+------------+
# |                toSt|Total_arrivals|Total_Volume|
# +--------------------+--------------+------------+
# |            Dead end|        202638| 3.7960738E7|
# |       BODY OF WATER|         32852|   9315257.0|
# |            DEAD END|         25380|   4836385.0|
# |Harlem River Shor...|         22597|   5384624.0|
# |Bronx River Shore...|         13173|   1980249.0|
# |            Dead End|         12004|   1624061.0|
# |           46 Avenue|         11317|    567782.0|
# |                BEND|         11142|   2825734.0|
# |       Flushing Line|          9348|    915322.0|
# |       8 Avenue Line|          9102|    990829.0|
# +--------------------+--------------+------------+
# only showing top 10 rows

# %%
print("Popular Routes (Departure -> Destination):")
popular_routes = data_df.groupBy("fromSt", "toSt",'Time').agg(
    count("*").alias("route_frequency"),
    sum("Vol").alias("total_volume")
).orderBy("route_frequency", ascending=False)
popular_routes.show(10)
# Out:
# Popular Routes (Departure -> Destination):
# +--------+--------+-----+---------------+------------+
# |  fromSt|    toSt| Time|route_frequency|total_volume|
# +--------+--------+-----+---------------+------------+
# |Dead End|Dead end| 8:30|            754|    180946.0|
# |Dead End|Dead end| 8:15|            753|    183678.0|
# |Dead End|Dead end| 7:45|            752|    182732.0|
# |Dead End|Dead end| 9:45|            750|    168656.0|
# |Dead End|Dead end| 7:30|            749|    181408.0|
# |Dead End|Dead end|10:15|            749|    168232.0|
# |Dead End|Dead end| 8:45|            749|    177118.0|
# |Dead End|Dead end|10:45|            749|    166930.0|
# |Dead End|Dead end|10:30|            748|    167949.0|
# |Dead End|Dead end| 2:45|            747|     29616.0|
# +--------+--------+-----+---------------+------------+
# only showing top 10 rows

# %%
print("Departure Trends with Time:")
departure_trends_time = data_df.groupBy("fromSt", "Time").agg(
    count("*").alias("total_departures"),
    sum("Vol").alias("total_volume")
).orderBy("total_departures", ascending=False)
departure_trends_time.show(10)

print("Destination Trends with Time:")
destination_trends_time = data_df.groupBy("toSt", "Time").agg(
    count("*").alias("total_arrivals"),
    sum("Vol").alias("total_volume")
).orderBy("total_arrivals", ascending=False)
destination_trends_time.show(10)
# Out:
# Departure Trends with Time:
# +--------+-----+----------------+------------+
# |  fromSt| Time|total_departures|total_volume|
# +--------+-----+----------------+------------+
# |Dead End| 7:30|            2016|    436243.0|
# |Dead End| 9:45|            2015|    413067.0|
# |Dead End| 8:15|            2014|    442786.0|
# |Dead End| 8:45|            2014|    429337.0|
# |Dead End| 7:15|            2014|    419434.0|
# |Dead End| 7:45|            2014|    443093.0|
# |Dead End|10:30|            2013|    411361.0|
# |Dead End|10:45|            2013|    412334.0|
# |Dead End| 9:30|            2012|    415057.0|
# |Dead End|10:15|            2012|    406715.0|
# +--------+-----+----------------+------------+
# only showing top 10 rows
#
# Destination Trends with Time:
# +--------+-----+--------------+------------+
# |    toSt| Time|total_arrivals|total_volume|
# +--------+-----+--------------+------------+
# |Dead end| 8:45|          2123|    492154.0|
# |Dead end| 8:30|          2122|    495082.0|
# |Dead end| 7:30|          2120|    498792.0|
# |Dead end| 8:15|          2120|    499322.0|
# |Dead end| 9:45|          2119|    480370.0|
# |Dead end| 7:45|          2119|    506155.0|
# |Dead end|14:15|          2116|    555272.0|
# |Dead end|13:15|          2116|    526023.0|
# |Dead end|12:45|          2116|    515109.0|
# |Dead end| 9:15|          2116|    477758.0|
# +--------+-----+--------------+------------+
# only showing top 10 rows

# %%
departures = data_df.groupBy("fromSt", "Time").agg(
    sum("Vol").alias("departures")
).withColumnRenamed("Time", "departure_time")

arrivals = data_df.groupBy("toSt", "Time").agg(
    sum("Vol").alias("arrivals")
).withColumnRenamed("Time", "arrival_time")

departures_alias = departures.alias("dep")
arrivals_alias = arrivals.alias("arr")

traffic_discrepancies = departures_alias.join(
    arrivals_alias,
    (col("dep.fromSt") == col("arr.toSt")) & (col("dep.departure_time") == col("arr.arrival_time")),
    "full_outer"
).select(
    coalesce(col("dep.fromSt"), col("arr.toSt")).alias("street"),
    coalesce(col("dep.departure_time"), col("arr.arrival_time")).alias("Time"),
    coalesce(col("dep.departures"), col("arr.arrivals")).alias("departures"),
    coalesce(col("arr.arrivals"), col("dep.departures")).alias("arrivals")
)

traffic_discrepancies = traffic_discrepancies.withColumn(
    "net_flow", col("departures") - col("arrivals")
)

traffic_discrepancies.orderBy("net_flow", ascending=False).show(10)

time_discrepancies = traffic_discrepancies.groupBy("Time").agg(
    sum("net_flow").alias("total_discrepancy")
).orderBy("total_discrepancy", ascending=False)
time_discrepancies.show(10)
# Out:
# +--------+-----+----------+--------+--------+
# |  street| Time|departures|arrivals|net_flow|
# +--------+-----+----------+--------+--------+
# |Dead End|17:15|  514808.0| 25401.0|489407.0|
# |Dead End|15:30|  512229.0| 24174.0|488055.0|
# |Dead End|16:15|  510908.0| 24665.0|486243.0|
# |Dead End|15:15|  509605.0| 24216.0|485389.0|
# |Dead End|15:45|  509000.0| 24109.0|484891.0|
# |Dead End|16:30|  509532.0| 24813.0|484719.0|
# |Dead End|17:30|  506843.0| 24586.0|482257.0|
# |Dead End|16:45|  506826.0| 24713.0|482113.0|
# |Dead End| 16:0|  502152.0| 24454.0|477698.0|
# |Dead End| 17:0|  501638.0| 25100.0|476538.0|
# +--------+-----+----------+--------+--------+
# only showing top 10 rows
#
# +-----+-----------------+
# | Time|total_discrepancy|
# +-----+-----------------+
# | 12:0|           6160.0|
# | 11:0|           5958.0|
# |14:10|              0.0|
# | 5:10|              0.0|
# |11:20|              0.0|
# | 9:50|              0.0|
# | 6:20|              0.0|
# | 2:20|              0.0|
# | 0:40|              0.0|
# |10:40|              0.0|
# +-----+-----------------+
# only showing top 10 rows

# %%
hubs = traffic_discrepancies.withColumn(
    "hub_type",
    when(col("net_flow") > 0, "Outflow Hub")
    .when(col("net_flow") < 0, "Inflow Hub")
    .otherwise("Balanced")
)

print("Inflow Hubs (Arrivals > Departures):")
hubs.filter(hubs["hub_type"] == "Inflow Hub").orderBy("net_flow", ascending=True).show(10)

print("Outflow Hubs (Departures > Arrivals):")
hubs.filter(hubs["hub_type"] == "Outflow Hub").orderBy("net_flow", ascending=False).show(10)
# Out:
# Inflow Hubs (Arrivals > Departures):
# +--------+-----+----------+--------+---------+----------+
# |  street| Time|departures|arrivals| net_flow|  hub_type|
# +--------+-----+----------+--------+---------+----------+
# |Dead end|15:30|   35963.0|576674.0|-540711.0|Inflow Hub|
# |Dead end|16:15|   35381.0|574529.0|-539148.0|Inflow Hub|
# |Dead end|17:15|   35636.0|574102.0|-538466.0|Inflow Hub|
# |Dead end|15:15|   36155.0|574413.0|-538258.0|Inflow Hub|
# |Dead end|15:45|   35406.0|570410.0|-535004.0|Inflow Hub|
# |Dead end|16:30|   35814.0|570726.0|-534912.0|Inflow Hub|
# |Dead end|16:45|   35687.0|569697.0|-534010.0|Inflow Hub|
# |Dead end| 16:0|   35792.0|568625.0|-532833.0|Inflow Hub|
# |Dead end|14:30|   34487.0|567074.0|-532587.0|Inflow Hub|
# |Dead end| 17:0|   35503.0|566887.0|-531384.0|Inflow Hub|
# +--------+-----+----------+--------+---------+----------+
# only showing top 10 rows
#
# Outflow Hubs (Departures > Arrivals):
# +--------+-----+----------+--------+--------+-----------+
# |  street| Time|departures|arrivals|net_flow|   hub_type|
# +--------+-----+----------+--------+--------+-----------+
# |Dead End|17:15|  514808.0| 25401.0|489407.0|Outflow Hub|
# |Dead End|15:30|  512229.0| 24174.0|488055.0|Outflow Hub|
# |Dead End|16:15|  510908.0| 24665.0|486243.0|Outflow Hub|
# |Dead End|15:15|  509605.0| 24216.0|485389.0|Outflow Hub|
# |Dead End|15:45|  509000.0| 24109.0|484891.0|Outflow Hub|
# |Dead End|16:30|  509532.0| 24813.0|484719.0|Outflow Hub|
# |Dead End|17:30|  506843.0| 24586.0|482257.0|Outflow Hub|
# |Dead End|16:45|  506826.0| 24713.0|482113.0|Outflow Hub|
# |Dead End| 16:0|  502152.0| 24454.0|477698.0|Outflow Hub|
# |Dead End| 17:0|  501638.0| 25100.0|476538.0|Outflow Hub|
# +--------+-----+----------+--------+--------+-----------+
# only showing top 10 rows

# %%
for row in hubs.collect():
    if row['hub_type'] == "Outflow Hub":
        print(f"Increase green signal duration for {row['street']}")
    elif row['hub_type'] == "Inflow Hub":
        print(f"Decrease green signal duration for {row['street']}")
# Out:
# Decrease green signal duration for 1 AV
# Increase green signal duration for 1 AV
# Increase green signal duration for 1 AV
# Increase green signal duration for 1 AV
# Decrease green signal duration for 1 AV
# Increase green signal duration for 1 AV
# Increase green signal duration for 1 AV
# Increase green signal duration for 1 AV
# Increase green signal duration for 1 AV
# Increase green signal duration for 1 AV
# Increase green signal duration for 1 AV
# Decrease green signal duration for 1 Avenue
# Decrease green signal duration for 1 Avenue
# Decrease green signal duration for 1 Avenue
# Decrease green signal duration for 1 Avenue
# Decrease green signal duration for 1 Avenue
# Decrease green signal duration for 1 Avenue
# Decrease green signal duration for 1 Avenue
# Decrease green signal duration for 1 Avenue
# Decrease green signal duration for 1 Avenue
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 AV
# Increase green signal duration for 10 Avenue
# Decrease green signal duration for 10 Avenue
# Decrease green signal duration for 10 Avenue
# Decrease green signal duration for 10 Avenue
# Decrease green signal duration for 10 Avenue
# Decrease green signal duration for 10 Avenue
# Decrease green signal duration for 10 Avenue
# Increase green signal duration for 10 Avenue
# Decrease green signal duration for 10 ST
# Decrease green signal duration for 10 ST
# Increase green signal duration for 10 ST
# Decrease green signal duration for 10 ST
# Decrease green signal duration for 10 ST
# Increase green signal duration for 10 ST
# Increase green signal duration for 100 Street
# Increase green signal duration for 100 Street
# Increase green signal duration for 100 Street
# Increase green signal duration for 100 Street
# Increase green signal duration for 100 Street
# Increase green signal duration for 100 Street
# Increase green signal duration for 100 Street
# Increase green signal duration for 100 Street
# Increase green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 AV
# Decrease green signal duration for 101 Street
# Decrease green signal duration for 101 Street
# Decrease green signal duration for 101 Street
# Decrease green signal duration for 101 Street
# Decrease green signal duration for 101 Street
# Decrease green signal duration for 101 Street
# Decrease green signal duration for 101 Street
# Decrease green signal duration for 101 Street
# Decrease green signal duration for 101 Street
# Decrease green signal duration for 101 Street
# Increase green signal duration for 104 ST
# Increase green signal duration for 104 ST
# Increase green signal duration for 104 ST
# Increase green signal duration for 104 ST
# Increase green signal duration for 104 ST
# Increase green signal duration for 104 ST
# Increase green signal duration for 104 ST
# Increase green signal duration for 105 Avenue
# Decrease green signal duration for 105 ST
# Decrease green signal duration for 105 ST
# Decrease green signal duration for 105 ST
# Decrease green signal duration for 105 ST
# Decrease green signal duration for 105 ST
# Decrease green signal duration for 105 ST
# Decrease green signal duration for 108 ST
# Increase green signal duration for 108 STREET
# Increase green signal duration for 108 STREET
# Increase green signal duration for 108 STREET
# Increase green signal duration for 108 STREET
# Decrease green signal duration for 109 AV
# Increase green signal duration for 109 AV
# Increase green signal duration for 109 AV
# Increase green signal duration for 109 AV
# Increase green signal duration for 109 AV
# Decrease green signal duration for 109 AV
# Increase green signal duration for 109 AV
# Increase green signal duration for 109 AV
# Increase green signal duration for 109 AV
# Increase green signal duration for 109 AV
# Decrease green signal duration for 109 AV
# Decrease green signal duration for 109 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Decrease green signal duration for 11 AV
# Increase green signal duration for 11 Avenue
# Increase green signal duration for 11 Avenue
# Increase green signal duration for 11 Avenue
# Increase green signal duration for 11 Avenue
# Increase green signal duration for 11 Avenue
# Increase green signal duration for 11 Avenue
# Increase green signal duration for 111 AV
# Increase green signal duration for 111 AV
# Increase green signal duration for 112 ST
# Increase green signal duration for 112 ST
# Increase green signal duration for 112 ST
# Increase green signal duration for 112 ST
# Increase green signal duration for 112 ST
# Increase green signal duration for 112 ST
# Decrease green signal duration for 115 Avenue
# Decrease green signal duration for 115 Avenue
# Increase green signal duration for 116 AV
# Increase green signal duration for 116 AV
# Decrease green signal duration for 116 AV
# Decrease green signal duration for 116 AV
# Increase green signal duration for 116 AV
# Decrease green signal duration for 116 AV
# Increase green signal duration for 116 AV
# Increase green signal duration for 116 AV
# Increase green signal duration for 12 AV
# Increase green signal duration for 12 AV
# Increase green signal duration for 12 AV
# Increase green signal duration for 12 AV
# Increase green signal duration for 12 AV
# Increase green signal duration for 12 AV
# Increase green signal duration for 12 AV
# Increase green signal duration for 12 AV
# Decrease green signal duration for 12 Avenue
# Decrease green signal duration for 12 Avenue
# Decrease green signal duration for 12 Avenue
# Decrease green signal duration for 12 Avenue
# Decrease green signal duration for 12 Avenue
# Decrease green signal duration for 12 Avenue
# Decrease green signal duration for 12 Avenue
# Decrease green signal duration for 12 Avenue
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 120 ST
# Decrease green signal duration for 130 ST
# Decrease green signal duration for 130 ST
# Decrease green signal duration for 130 ST
# Decrease green signal duration for 130 ST
# Decrease green signal duration for 130 ST
# Decrease green signal duration for 130 ST
# Decrease green signal duration for 130 Street
# Decrease green signal duration for 130 Street
# Increase green signal duration for 131 ST
# Increase green signal duration for 131 ST
# Decrease green signal duration for 131 ST
# Decrease green signal duration for 131 ST
# Increase green signal duration for 131 ST
# Increase green signal duration for 131 ST
# Increase green signal duration for 131 ST
# Decrease green signal duration for 131 ST
# Increase green signal duration for 131 Street
# Increase green signal duration for 131 Street
# Increase green signal duration for 131 Street
# Increase green signal duration for 131 Street
# Increase green signal duration for 131 Street
# Increase green signal duration for 131 Street
# Decrease green signal duration for 131 Street
# Decrease green signal duration for 131 Street
# Decrease green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Increase green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Increase green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Decrease green signal duration for 139 Street
# Increase green signal duration for 14 Street/canarsie Line
# Increase green signal duration for 14 Street/canarsie Line
# Increase green signal duration for 14 Street/canarsie Line
# Increase green signal duration for 14 Street/canarsie Line
# Increase green signal duration for 14 Street/canarsie Line
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Decrease green signal duration for 145 RD
# Increase green signal duration for 145 ST BR
# Decrease green signal duration for 146 ST
# Decrease green signal duration for 146 ST
# Decrease green signal duration for 146 ST
# Decrease green signal duration for 146 ST
# Decrease green signal duration for 146 ST
# Decrease green signal duration for 146 ST
# Decrease green signal duration for 146 ST
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 147 Street
# Decrease green signal duration for 159 Street
# Decrease green signal duration for 159 Street
# Increase green signal duration for 164 ST
# Increase green signal duration for 164 ST
# Increase green signal duration for 164 ST
# Increase green signal duration for 164 ST
# Increase green signal duration for 164 ST
# Increase green signal duration for 164 ST
# Increase green signal duration for 164 ST
# Increase green signal duration for 164 ST
# Increase green signal duration for 164 ST
# Increase green signal duration for 18 AV
# Increase green signal duration for 18 AV
# Increase green signal duration for 18 AV
# Increase green signal duration for 18 AV
# Increase green signal duration for 18 AV
# Increase green signal duration for 18 AV
# Increase green signal duration for 18 AV
# Increase green signal duration for 18 AV
# Decrease green signal duration for 183 ST
# Decrease green signal duration for 183 ST
# Decrease green signal duration for 183 ST
# Decrease green signal duration for 183 Street
# Increase green signal duration for 184 ST
# Decrease green signal duration for 184 ST
# Decrease green signal duration for 184 ST
# Decrease green signal duration for 184 ST
# Increase green signal duration for 184 ST
# Increase green signal duration for 184 ST
# Increase green signal duration for 184 ST
# Increase green signal duration for 19 AV
# Increase green signal duration for 19 AV
# Increase green signal duration for 19 AV
# Increase green signal duration for 19 AV
# Increase green signal duration for 19 AV
# Increase green signal duration for 19 AV
# Increase green signal duration for 19 AV
# Increase green signal duration for 19 AV
# Increase green signal duration for 19 AV
# Increase green signal duration for 19 AV
# Increase green signal duration for 190 Street
# Increase green signal duration for 190 Street
# Increase green signal duration for 190 Street
# Increase green signal duration for 190 Street
# Increase green signal duration for 190 Street
# Increase green signal duration for 190 Street
# Increase green signal duration for 190 Street
# Increase green signal duration for 190 Street
# Increase green signal duration for 190 Street
# Increase green signal duration for 190 Street
# Decrease green signal duration for 2 AV
# Decrease green signal duration for 2 AV
# Decrease green signal duration for 2 AV
# Increase green signal duration for 2 AV
# Increase green signal duration for 2 AV
# Increase green signal duration for 2 AV
# Decrease green signal duration for 2 AV
# Decrease green signal duration for 2 AV
# Increase green signal duration for 2 AV
# Increase green signal duration for 2 AVENUE
# Increase green signal duration for 2 AVENUE
# Increase green signal duration for 2 AVENUE
# Increase green signal duration for 2 AVENUE
# Increase green signal duration for 2 AVENUE
# Increase green signal duration for 2 AVENUE
# Increase green signal duration for 2 AVENUE
# Increase green signal duration for 2 AVENUE
# Increase green signal duration for 2 Avenue
# Increase green signal duration for 2 Avenue
# Increase green signal duration for 2 Avenue
# Increase green signal duration for 2 Avenue
# Increase green signal duration for 2 Avenue
# Increase green signal duration for 2 Avenue
# Increase green signal duration for 2 Avenue
# Increase green signal duration for 2 Avenue
# Increase green signal duration for 2 Avenue
# Decrease green signal duration for 20 Avenue
# Increase green signal duration for 21 ST
# Increase green signal duration for 21 ST
# Increase green signal duration for 21 ST
# Increase green signal duration for 21 ST
# Increase green signal duration for 21 ST
# Increase green signal duration for 21 ST
# Increase green signal duration for 21 ST
# Increase green signal duration for 21 ST
# Increase green signal duration for 21 ST
# Increase green signal duration for 21 ST
# Decrease green signal duration for 217 ST
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 222 Street
# Decrease green signal duration for 24 AV
# Decrease green signal duration for 3 AV
# Decrease green signal duration for 3 AV
# Decrease green signal duration for 3 AV
# Decrease green signal duration for 3 AV
# Decrease green signal duration for 3 AV
# Decrease green signal duration for 3 AV
# Decrease green signal duration for 3 AV
# Decrease green signal duration for 3 AV
# Decrease green signal duration for 3 AV
# Decrease green signal duration for 3 AVENUE
# Increase green signal duration for 3 AVENUE
# Decrease green signal duration for 3 AVENUE
# Decrease green signal duration for 3 Avenue
# Decrease green signal duration for 3 Avenue
# Increase green signal duration for 3 ST
# Increase green signal duration for 3 ST
# Decrease green signal duration for 3 ST
# Decrease green signal duration for 3 ST
# Decrease green signal duration for 3 ST
# Increase green signal duration for 3 ST
# Increase green signal duration for 3 Street
# Increase green signal duration for 3 Street
# Increase green signal duration for 3 Street
# Increase green signal duration for 3 Street
# Increase green signal duration for 3 Street
# Increase green signal duration for 3 Street
# Increase green signal duration for 3 Street
# Increase green signal duration for 3 Street
# Increase green signal duration for 3 Street
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 Avenue
# Increase green signal duration for 30 RD
# Increase green signal duration for 30 RD
# Increase green signal duration for 30 RD
# Increase green signal duration for 30 RD
# Increase green signal duration for 30 RD
# Increase green signal duration for 30 RD
# Increase green signal duration for 30 RD
# Decrease green signal duration for 30 ST
# Decrease green signal duration for 30 ST
# Decrease green signal duration for 30 ST
# Decrease green signal duration for 30 ST
# Decrease green signal duration for 30 ST
# Decrease green signal duration for 30 ST
# Decrease green signal duration for 30 ST
# Decrease green signal duration for 30 ST
# Increase green signal duration for 30 ST
# Decrease green signal duration for 30 ST
# Increase green signal duration for 30 ST
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Increase green signal duration for 31 Street
# Decrease green signal duration for 35 AV
# Decrease green signal duration for 35 AV
# Decrease green signal duration for 35 AV
# Decrease green signal duration for 35 AV
# Decrease green signal duration for 35 AV
# Decrease green signal duration for 35 AV
# Decrease green signal duration for 35 AV
# Decrease green signal duration for 35 AV
# Increase green signal duration for 35 AVENUE
# Increase green signal duration for 35 AVENUE
# Increase green signal duration for 35 AVENUE
# Increase green signal duration for 35 AVENUE
# Increase green signal duration for 36 Avenue
# Increase green signal duration for 36 Avenue
# Increase green signal duration for 36 Avenue
# Increase green signal duration for 36 Avenue
# Increase green signal duration for 36 Avenue
# Increase green signal duration for 36 Avenue
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Increase green signal duration for 37 AV
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 AVENUE
# Decrease green signal duration for 37 Avenue
# Decrease green signal duration for 37 Avenue
# Decrease green signal duration for 37 Avenue
# Decrease green signal duration for 37 Avenue
# Decrease green signal duration for 37 Avenue
# Decrease green signal duration for 37 Avenue
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 37 Street
# Decrease green signal duration for 38 Avenue
# Decrease green signal duration for 38 Avenue
# Decrease green signal duration for 38 Avenue
# Decrease green signal duration for 38 Avenue
# Decrease green signal duration for 38 Avenue
# Decrease green signal duration for 38 Avenue
# Decrease green signal duration for 38 Avenue
# Decrease green signal duration for 38 Avenue
# Decrease green signal duration for 38 Avenue
# Increase green signal duration for 38 ST
# Decrease green signal duration for 38 ST
# Decrease green signal duration for 38 ST
# Increase green signal duration for 38 ST
# Increase green signal duration for 38 ST
# Increase green signal duration for 38 ST
# Increase green signal duration for 38 ST
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Increase green signal duration for 39 Avenue
# Increase green signal duration for 39 Avenue
# Increase green signal duration for 39 Avenue
# Increase green signal duration for 39 Avenue
# Increase green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 39 Avenue
# Decrease green signal duration for 4 AV
# Decrease green signal duration for 4 AV
# Decrease green signal duration for 4 AV
# Decrease green signal duration for 4 AV
# Decrease green signal duration for 4 AV
# Decrease green signal duration for 4 AV
# Decrease green signal duration for 4 AV
# Decrease green signal duration for 4 AV
# Increase green signal duration for 4 Avenue
# Increase green signal duration for 4 Avenue
# Increase green signal duration for 4 Avenue
# Increase green signal duration for 4 Avenue
# Increase green signal duration for 4 Avenue
# Increase green signal duration for 4 Avenue
# Decrease green signal duration for 4 Avenue
# Decrease green signal duration for 4 Avenue
# Decrease green signal duration for 4 Avenue
# Decrease green signal duration for 4 Avenue
# Increase green signal duration for 4 Avenue
# Increase green signal duration for 4 Avenue
# Decrease green signal duration for 40 Avenue
# Decrease green signal duration for 40 Avenue
# Decrease green signal duration for 40 Avenue
# Decrease green signal duration for 40 Avenue
# Decrease green signal duration for 40 Avenue
# Decrease green signal duration for 40 Avenue
# Decrease green signal duration for 40 Avenue
# Decrease green signal duration for 40 Avenue
# Decrease green signal duration for 40 Avenue
# Increase green signal duration for 42 Street
# Decrease green signal duration for 43 Avenue
# Decrease green signal duration for 43 Avenue
# Decrease green signal duration for 43 Avenue
# Decrease green signal duration for 43 Avenue
# Decrease green signal duration for 43 Avenue
# Decrease green signal duration for 43 Avenue
# Decrease green signal duration for 43 Avenue
# Decrease green signal duration for 43 Street
# Decrease green signal duration for 43 Street
# Decrease green signal duration for 43 Street
# Increase green signal duration for 43 Street
# Increase green signal duration for 43 Street
# Increase green signal duration for 43 Street
# Increase green signal duration for 43 Street
# Increase green signal duration for 43 Street
# Decrease green signal duration for 44 AV
# Decrease green signal duration for 44 AV
# Decrease green signal duration for 44 AV
# Decrease green signal duration for 44 AV
# Decrease green signal duration for 44 AV
# Increase green signal duration for 44 AV
# Decrease green signal duration for 44 Street
# Decrease green signal duration for 44 Street
# Decrease green signal duration for 44 Street
# Decrease green signal duration for 44 Street
# Decrease green signal duration for 44 Street
# Decrease green signal duration for 44 Street
# Decrease green signal duration for 44 Street
# Decrease green signal duration for 44 Street
# Decrease green signal duration for 44 Street
# Decrease green signal duration for 46 Avenue
# Decrease green signal duration for 46 Avenue
# Decrease green signal duration for 46 Avenue
# Decrease green signal duration for 46 Avenue
# Decrease green signal duration for 46 Avenue
# Decrease green signal duration for 46 Avenue
# Decrease green signal duration for 46 Avenue
# Decrease green signal duration for 46 Avenue
# Decrease green signal duration for 47 Avenue
# Decrease green signal duration for 47 Avenue
# Decrease green signal duration for 47 Avenue
# Decrease green signal duration for 47 Avenue
# Decrease green signal duration for 47 Avenue
# Decrease green signal duration for 47 Avenue
# Decrease green signal duration for 47 Avenue
# Decrease green signal duration for 47 Avenue
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Decrease green signal duration for 47 RD
# Increase green signal duration for 48 Avenue
# Increase green signal duration for 5 AV
# Increase green signal duration for 5 AV
# Increase green signal duration for 5 AV
# Increase green signal duration for 5 AV
# Increase green signal duration for 5 Avenue
# Increase green signal duration for 5 Avenue
# Increase green signal duration for 5 Avenue
# Increase green signal duration for 5 Avenue
# Increase green signal duration for 5 Avenue
# Increase green signal duration for 5 Avenue
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Increase green signal duration for 5 ST
# Decrease green signal duration for 51 ST
# Decrease green signal duration for 51 ST
# Decrease green signal duration for 51 ST
# Decrease green signal duration for 51 ST
# Decrease green signal duration for 51 ST
# Decrease green signal duration for 51 ST
# Decrease green signal duration for 51 ST
# Increase green signal duration for 51 ST
# Increase green signal duration for 51 ST
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Decrease green signal duration for 52 Avenue
# Increase green signal duration for 53 Avenue
# Increase green signal duration for 53 Avenue
# Increase green signal duration for 53 Avenue
# Decrease green signal duration for 53 Avenue
# Decrease green signal duration for 53 Avenue
# Increase green signal duration for 53 ST
# Decrease green signal duration for 53 ST
# Decrease green signal duration for 53 ST
# Increase green signal duration for 53 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Decrease green signal duration for 54 ST
# Decrease green signal duration for 54 ST
# Increase green signal duration for 54 ST
# Decrease green signal duration for 55 Avenue
# Decrease green signal duration for 55 Avenue
# Decrease green signal duration for 55 Avenue
# Decrease green signal duration for 55 ST
# Decrease green signal duration for 55 ST
# Increase green signal duration for 55 ST
# Increase green signal duration for 55 ST
# Increase green signal duration for 55 ST
# Increase green signal duration for 56 AV
# Decrease green signal duration for 56 ST
# Decrease green signal duration for 56 ST
# Decrease green signal duration for 56 ST
# Decrease green signal duration for 56 ST
# Decrease green signal duration for 56 ST
# Decrease green signal duration for 56 ST
# Decrease green signal duration for 56 ST
# Decrease green signal duration for 56 ST
# Decrease green signal duration for 56 Street
# Increase green signal duration for 6 Avenue
# Increase green signal duration for 6 Avenue
# Increase green signal duration for 6 Avenue
# Decrease green signal duration for 6 Avenue
# Decrease green signal duration for 6 Avenue
# Decrease green signal duration for 6 Avenue
# Increase green signal duration for 6 Avenue
# Increase green signal duration for 6 Avenue
# Increase green signal duration for 6 Avenue
# Increase green signal duration for 6 Avenue
# Increase green signal duration for 6 Avenue
# Increase green signal duration for 6 Avenue
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Increase green signal duration for 6 Avenue Line
# Decrease green signal duration for 6 ST
# Decrease green signal duration for 6 ST
# Decrease green signal duration for 6 ST
# Decrease green signal duration for 6 ST
# Decrease green signal duration for 6 ST
# Decrease green signal duration for 6 ST
# Decrease green signal duration for 6 ST
# Increase green signal duration for 60 RD
# Decrease green signal duration for 60 RD
# Increase green signal duration for 60 RD
# Decrease green signal duration for 60 RD
# Increase green signal duration for 60 RD
# Increase green signal duration for 60 RD
# Decrease green signal duration for 60 RD
# Decrease green signal duration for 60 ST
# Decrease green signal duration for 60 ST
# Decrease green signal duration for 60 ST
# Decrease green signal duration for 60 Street
# Decrease green signal duration for 60 Street
# Decrease green signal duration for 60 Street
# Decrease green signal duration for 60 Street
# Decrease green signal duration for 60 Street
# Decrease green signal duration for 60 Street
# Decrease green signal duration for 60 Street
# Decrease green signal duration for 60 Street
# Increase green signal duration for 62 DR
# Decrease green signal duration for 63 AV
# Increase green signal duration for 63 AV
# Decrease green signal duration for 63 AV
# Increase green signal duration for 63 AV
# Increase green signal duration for 63 AV
# Increase green signal duration for 63 AV
# Decrease green signal duration for 63 AV
# Decrease green signal duration for 63 AV
# Increase green signal duration for 63 Street Line
# Increase green signal duration for 63 Street Line
# Increase green signal duration for 63 Street Line
# Increase green signal duration for 63 Street Line
# Increase green signal duration for 63 Street Line
# Increase green signal duration for 63 Street Line
# Decrease green signal duration for 63 Street Line
# Decrease green signal duration for 63 Street Line
# Decrease green signal duration for 63 Street Line
# Increase green signal duration for 64 ST
# Increase green signal duration for 64 ST
# Increase green signal duration for 64 ST
# Increase green signal duration for 64 ST
# Increase green signal duration for 64 ST
# Increase green signal duration for 64 ST
# Increase green signal duration for 64 ST
# Increase green signal duration for 64 ST
# Increase green signal duration for 64 ST
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 64 Street
# Increase green signal duration for 65 ST
# Increase green signal duration for 65 ST
# Increase green signal duration for 65 ST
# Increase green signal duration for 65 ST
# Decrease green signal duration for 65 Street
# Decrease green signal duration for 65 Street
# Decrease green signal duration for 65 Street
# Decrease green signal duration for 65 Street
# Decrease green signal duration for 65 Street
# Decrease green signal duration for 65 Street
# Decrease green signal duration for 67 ST
# Increase green signal duration for 67 ST
# Increase green signal duration for 67 ST
# Increase green signal duration for 67 ST
# Increase green signal duration for 67 ST
# Increase green signal duration for 67 ST
# Increase green signal duration for 67 ST
# Increase green signal duration for 67 ST
# Increase green signal duration for 67 ST
# Decrease green signal duration for 68 ST
# Decrease green signal duration for 68 ST
# Decrease green signal duration for 68 ST
# Decrease green signal duration for 68 ST
# Decrease green signal duration for 68 ST
# Decrease green signal duration for 68 ST
# Increase green signal duration for 68 Street
# Increase green signal duration for 68 Street
# Increase green signal duration for 68 Street
# Increase green signal duration for 68 Street
# Increase green signal duration for 68 Street
# Increase green signal duration for 68 Street
# Decrease green signal duration for 68 Street
# Decrease green signal duration for 68 Street
# Decrease green signal duration for 68 Street
# Decrease green signal duration for 68 Street
# Decrease green signal duration for 69 ST
# Increase green signal duration for 69 ST
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 69 Street
# Increase green signal duration for 7 AV
# Increase green signal duration for 7 AV
# Increase green signal duration for 7 AV
# Increase green signal duration for 7 AV
# Increase green signal duration for 7 AV
# Increase green signal duration for 7 AV
# Increase green signal duration for 7 AV
# Increase green signal duration for 7 AV
# Increase green signal duration for 7 AV
# Increase green signal duration for 7 Avenue
# Increase green signal duration for 7 Avenue
# Increase green signal duration for 7 Avenue
# Increase green signal duration for 7 Avenue
# Increase green signal duration for 7 Avenue
# Increase green signal duration for 7 Avenue
# Increase green signal duration for 7 Avenue
# Increase green signal duration for 7 Avenue
# Increase green signal duration for 7 Avenue
# Increase green signal duration for 70 ST
# Increase green signal duration for 70 ST
# Increase green signal duration for 70 ST
# Increase green signal duration for 70 ST
# Decrease green signal duration for 70 ST
# Decrease green signal duration for 70 ST
# Increase green signal duration for 70 ST
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Decrease green signal duration for 70 Street
# Increase green signal duration for 71 AV
# Decrease green signal duration for 71 AV
# Increase green signal duration for 71 AV
# Increase green signal duration for 71 AV
# Increase green signal duration for 71 AV
# Increase green signal duration for 71 AV
# Increase green signal duration for 71 AV
# Increase green signal duration for 71 AV
# Increase green signal duration for 71 AV
# Increase green signal duration for 71 AV
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 72 Street
# Increase green signal duration for 73 AV
# Decrease green signal duration for 74 Street
# Decrease green signal duration for 74 Street
# Decrease green signal duration for 74 Street
# Decrease green signal duration for 74 Street
# Decrease green signal duration for 74 Street
# Decrease green signal duration for 74 Street
# Decrease green signal duration for 74 Street
# Decrease green signal duration for 74 Street
# Decrease green signal duration for 74 Street
# Decrease green signal duration for 75 AV
# Decrease green signal duration for 75 AV
# Decrease green signal duration for 75 AV
# Decrease green signal duration for 75 AV
# Decrease green signal duration for 75 AV
# Increase green signal duration for 75 ST
# Increase green signal duration for 75 ST
# Increase green signal duration for 75 ST
# Increase green signal duration for 75 ST
# Increase green signal duration for 75 ST
# Increase green signal duration for 75 ST
# Increase green signal duration for 75 ST
# Increase green signal duration for 75 Street
# Increase green signal duration for 75 Street
# Increase green signal duration for 75 Street
# Increase green signal duration for 75 Street
# Increase green signal duration for 75 Street
# Increase green signal duration for 75 Street
# Increase green signal duration for 75 Street
# Increase green signal duration for 75 Street
# Increase green signal duration for 76 ST
# Increase green signal duration for 76 ST
# Increase green signal duration for 76 ST
# Increase green signal duration for 76 ST
# Increase green signal duration for 76 ST
# Increase green signal duration for 76 ST
# Increase green signal duration for 76 ST
# Increase green signal duration for 76 ST
# Increase green signal duration for 76 ST
# Increase green signal duration for 76 ST
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 AV
# Increase green signal duration for 77 RD
# Increase green signal duration for 77 RD
# Increase green signal duration for 77 RD
# Increase green signal duration for 77 RD
# Increase green signal duration for 77 RD
# Increase green signal duration for 77 RD
# Increase green signal duration for 77 RD
# Increase green signal duration for 77 RD
# Increase green signal duration for 77 RD
# Increase green signal duration for 77 RD
# Decrease green signal duration for 77 ST
# Decrease green signal duration for 77 ST
# Decrease green signal duration for 77 ST
# Decrease green signal duration for 77 ST
# Decrease green signal duration for 77 ST
# Decrease green signal duration for 77 ST
# Decrease green signal duration for 77 ST
# Decrease green signal duration for 77 ST
# Decrease green signal duration for 77 ST
# Decrease green signal duration for 78 AV
# Decrease green signal duration for 78 AV
# Decrease green signal duration for 78 AV
# Decrease green signal duration for 78 AV
# Decrease green signal duration for 78 AV
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Increase green signal duration for 78 ST
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 AV
# Decrease green signal duration for 8 Avenue
# Decrease green signal duration for 8 Avenue
# Decrease green signal duration for 8 Avenue
# Decrease green signal duration for 8 Avenue
# Decrease green signal duration for 8 Avenue
# Decrease green signal duration for 8 Avenue
# Decrease green signal duration for 8 Avenue Line
# Decrease green signal duration for 8 Avenue Line
# Decrease green signal duration for 8 Avenue Line
# Decrease green signal duration for 8 Avenue Line
# Decrease green signal duration for 8 Avenue Line
# Decrease green signal duration for 8 Avenue Line
# Decrease green signal duration for 8 Avenue Line
# Increase green signal duration for 8 Street
# Decrease green signal duration for 8 Street
# Decrease green signal duration for 8 Street
# Decrease green signal duration for 8 Street
# Increase green signal duration for 8 Street
# Increase green signal duration for 8 Street
# Increase green signal duration for 8 Street
# Decrease green signal duration for 8 Street
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 80 ST
# Decrease green signal duration for 81 ST
# Decrease green signal duration for 81 ST
# Decrease green signal duration for 81 ST
# Decrease green signal duration for 81 ST
# Decrease green signal duration for 81 ST
# Decrease green signal duration for 81 ST
# Decrease green signal duration for 81 ST
# Decrease green signal duration for 81 ST
# Decrease green signal duration for 82 ST
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 82 Street
# Decrease green signal duration for 84 ST
# Decrease green signal duration for 85 ST
# Increase green signal duration for 85 Street
# Increase green signal duration for 85 Street
# Increase green signal duration for 85 Street
# Increase green signal duration for 85 Street
# Increase green signal duration for 85 Street
# Increase green signal duration for 85 Street
# Increase green signal duration for 85 Street
# Increase green signal duration for 85 Street
# Increase green signal duration for 86 ST
# Increase green signal duration for 86 ST
# Increase green signal duration for 86 ST
# Increase green signal duration for 86 ST
# Decrease green signal duration for 86 Street
# Decrease green signal duration for 86 Street
# Decrease green signal duration for 86 Street
# Decrease green signal duration for 86 Street
# Increase green signal duration for 87 DR
# Decrease green signal duration for 87 DR
# Increase green signal duration for 87 DR
# Decrease green signal duration for 87 DR
# Decrease green signal duration for 87 DR
# Decrease green signal duration for 87 DR
# Decrease green signal duration for 87 DR
# Decrease green signal duration for 87 DR
# Increase green signal duration for 87 DR
# Decrease green signal duration for 87 DR
# Decrease green signal duration for 87 DR
# Decrease green signal duration for 87 DR
# Increase green signal duration for 87 DR
# Increase green signal duration for 87 DR
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 87 Street
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Decrease green signal duration for 89 AV
# Increase green signal duration for 9 Avenue
# Decrease green signal duration for 9 Avenue
# Decrease green signal duration for 9 Avenue
# Decrease green signal duration for 9 Avenue
# Decrease green signal duration for 9 Avenue
# Decrease green signal duration for 9 Avenue
# Decrease green signal duration for 9 Avenue
# Decrease green signal duration for 9 Avenue
# Increase green signal duration for 9 Avenue
# Increase green signal duration for 9 ST
# Increase green signal duration for 9 ST
# Increase green signal duration for 9 ST
# Increase green signal duration for 9 ST
# Increase green signal duration for 9 ST
# Increase green signal duration for 9 ST
# Increase green signal duration for 9 ST
# Decrease green signal duration for 9 ST BR
# Decrease green signal duration for 9 ST BR
# Decrease green signal duration for 9 ST BR
# ...
# Increase green signal duration for W 12 ST
# Increase green signal duration for W 12 ST
# Increase green signal duration for W 12 ST
# Increase green signal duration for W 12 ST
# Increase green signal duration for W 12 ST
# Decrease green signal duration for W 13 ST
# Decrease green signal duration for W 13 ST
# Decrease green signal duration for W 13 ST
# Decrease green signal duration for W 13 ST
# Decrease green signal duration for W 13 ST
# Decrease green signal duration for W 13 ST
# Decrease green signal duration for W 13 ST
# Decrease green signal duration for W 134 ST
# Decrease green signal duration for W 134 ST
# Decrease green signal duration for W 134 ST
# Decrease green signal duration for W 134 ST
# Decrease green signal duration for W 134 ST
# Decrease green signal duration for W 134 ST
# Increase green signal duration for W 135 ST
# Increase green signal duration for W 135 ST
# Increase green signal duration for W 135 ST
# Increase green signal duration for W 135 ST
# Increase green signal duration for W 135 ST
# Increase green signal duration for W 135 ST
# Increase green signal duration for W 135 ST
# Decrease green signal duration for W 136 ST
# Decrease green signal duration for W 136 ST
# Decrease green signal duration for W 136 ST
# Decrease green signal duration for W 174 ST
# Decrease green signal duration for W 174 ST
# Decrease green signal duration for W 174 ST
# Decrease green signal duration for W 174 ST
# Decrease green signal duration for W 174 ST
# Increase green signal duration for W 174 ST
# Decrease green signal duration for W 174 ST
# Increase green signal duration for W 204 ST
# Increase green signal duration for W 204 ST
# Increase green signal duration for W 204 ST
# Increase green signal duration for W 204 ST
# Increase green signal duration for W 204 ST
# Increase green signal duration for W 204 ST
# Increase green signal duration for W 204 ST
# Increase green signal duration for W 204 ST
# Increase green signal duration for W 262 ST
# Decrease green signal duration for W 44 ST
# Decrease green signal duration for W 44 ST
# Decrease green signal duration for W 44 ST
# Increase green signal duration for W 44 ST
# Decrease green signal duration for W 44 ST
# Increase green signal duration for W 44 ST
# Decrease green signal duration for W 44 ST
# Decrease green signal duration for W 44 ST
# Increase green signal duration for W 44 ST
# Decrease green signal duration for W 6 ST
# Decrease green signal duration for W 6 ST
# Decrease green signal duration for W 6 ST
# Decrease green signal duration for W 6 ST
# Decrease green signal duration for W 6 ST
# Decrease green signal duration for W 6 ST
# Decrease green signal duration for W 6 ST
# Decrease green signal duration for W 6 ST
# Decrease green signal duration for W 6 ST
# Decrease green signal duration for W 6 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Increase green signal duration for W 60 ST
# Decrease green signal duration for W 61 ST
# Decrease green signal duration for W 61 ST
# Decrease green signal duration for W 61 ST
# Decrease green signal duration for W 61 ST
# Decrease green signal duration for W 71 ST
# Decrease green signal duration for W 71 ST
# Decrease green signal duration for W 71 ST
# Decrease green signal duration for W 71 ST
# Decrease green signal duration for W 71 ST
# Decrease green signal duration for W 71 ST
# Decrease green signal duration for W 71 ST
# Decrease green signal duration for W 71 ST
# Decrease green signal duration for W 71 ST
# Decrease green signal duration for W 72 ST
# Decrease green signal duration for W 72 ST
# Decrease green signal duration for W 72 ST
# Decrease green signal duration for W 72 ST
# Decrease green signal duration for W 72 ST
# Increase green signal duration for W 75 ST
# Decrease green signal duration for W 75 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 78 ST
# Decrease green signal duration for W 79 ST
# Decrease green signal duration for W 86 ST
# Decrease green signal duration for W 86 ST
# Decrease green signal duration for W 86 ST
# Decrease green signal duration for W 96 ST
# Decrease green signal duration for W 96 ST
# Decrease green signal duration for W 96 ST
# Increase green signal duration for W 96 ST
# Increase green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Increase green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Increase green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Increase green signal duration for W 96 ST/HHP NB EXIT 11/HHP NB EN W 96 ST
# Decrease green signal duration for W 97 ST
# Decrease green signal duration for W 97 ST
# Decrease green signal duration for W 97 ST
# Decrease green signal duration for W 97 ST
# Decrease green signal duration for W 97 ST
# Decrease green signal duration for W 97 ST
# Increase green signal duration for WASHINGTON AV
# Increase green signal duration for WASHINGTON AV
# Decrease green signal duration for WASHINGTON AV
# Increase green signal duration for WASHINGTON AV
# Decrease green signal duration for WEBSTER AV
# Decrease green signal duration for WEST END AV
# Decrease green signal duration for WEST END AV
# Decrease green signal duration for WEST END AV
# Decrease green signal duration for WEST END AV
# Decrease green signal duration for WEST END AV
# Decrease green signal duration for WEST END AV
# Decrease green signal duration for WEST END AV
# Increase green signal duration for WEST ST
# Increase green signal duration for WEST ST
# Increase green signal duration for WEST ST
# Increase green signal duration for WEST ST
# Increase green signal duration for WEST ST
# Increase green signal duration for WEST ST
# Decrease green signal duration for WEST ST
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WESTMINSTER RD
# Increase green signal duration for WHITESTONE EXWY
# Increase green signal duration for WHITESTONE EXWY
# Increase green signal duration for WHITESTONE EXWY
# Increase green signal duration for WHITESTONE EXWY
# Increase green signal duration for WHITESTONE EXWY
# Increase green signal duration for WHITESTONE EXWY
# Increase green signal duration for WHITESTONE EXWY
# Increase green signal duration for WINDSOR RD
# Increase green signal duration for WINDSOR RD
# Increase green signal duration for WINDSOR RD
# Increase green signal duration for WINDSOR RD
# Increase green signal duration for WINDSOR RD
# Increase green signal duration for WINDSOR RD
# Increase green signal duration for WINDSOR RD
# Increase green signal duration for WINDSOR RD
# Increase green signal duration for WINDSOR RD
# Increase green signal duration for WOODBINE ST
# Increase green signal duration for WOODBINE ST
# Increase green signal duration for WOODBINE ST
# Increase green signal duration for WOODBINE ST
# Decrease green signal duration for WOODBINE ST
# Increase green signal duration for WOODBINE ST
# Increase green signal duration for WOODBINE ST
# Decrease green signal duration for WOODBINE ST
# Decrease green signal duration for WOODBINE ST
# Increase green signal duration for WOODBINE ST
# Increase green signal duration for WOODBINE ST
# Increase green signal duration for WOODBINE ST
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WOODHAVEN BLVD
# Decrease green signal duration for WYCKOFF AV
# Decrease green signal duration for WYCKOFF AV
# Decrease green signal duration for WYCKOFF AV
# Decrease green signal duration for WYCKOFF AV
# Decrease green signal duration for WYCKOFF AV
# Decrease green signal duration for WYCKOFF AV
# Decrease green signal duration for WYTHE AV
# Decrease green signal duration for WYTHE AV
# Decrease green signal duration for WYTHE AV
# Decrease green signal duration for WYTHE AV
# Decrease green signal duration for WYTHE AV
# Increase green signal duration for WYTHE AV
# Increase green signal duration for WYTHE AV
# Decrease green signal duration for Wadsworth Avenue
# Decrease green signal duration for Wadsworth Avenue
# Decrease green signal duration for Wadsworth Avenue
# Decrease green signal duration for Wadsworth Avenue
# Decrease green signal duration for Wadsworth Avenue
# Decrease green signal duration for Wadsworth Avenue
# Decrease green signal duration for Wadsworth Avenue
# Decrease green signal duration for Wallace Avenue
# Decrease green signal duration for Wallace Avenue
# Decrease green signal duration for Wallace Avenue
# Decrease green signal duration for Wallace Avenue
# Decrease green signal duration for Wallace Avenue
# Decrease green signal duration for Wallace Avenue
# Decrease green signal duration for Wallace Avenue
# Decrease green signal duration for Wallace Avenue
# Decrease green signal duration for Wallace Avenue
# Increase green signal duration for Washington Avenue
# Increase green signal duration for Washington Avenue
# Increase green signal duration for Washington Avenue
# Increase green signal duration for Washington Avenue
# Increase green signal duration for Washington Avenue
# Increase green signal duration for Washington Avenue
# Increase green signal duration for Washington Avenue
# Increase green signal duration for Washington Avenue
# Increase green signal duration for Washington Avenue
# Decrease green signal duration for Washington Bridge
# Increase green signal duration for Washington Bridge
# Decrease green signal duration for Washington Bridge
# Decrease green signal duration for Washington Bridge
# Decrease green signal duration for Washington Bridge
# Increase green signal duration for Washington Bridge
# Increase green signal duration for Washington Bridge
# Increase green signal duration for Washington Bridge
# Decrease green signal duration for Washington Bridge
# Increase green signal duration for Washington Bridge
# Increase green signal duration for Washington Bridge
# Increase green signal duration for Webster Avenue
# Increase green signal duration for Webster Avenue
# Decrease green signal duration for Webster Avenue
# Increase green signal duration for Webster Avenue
# Increase green signal duration for Webster Avenue
# Increase green signal duration for Webster Avenue
# Increase green signal duration for Webster Avenue
# Increase green signal duration for Webster Avenue
# Increase green signal duration for Webster Avenue
# Increase green signal duration for Webster Avenue
# Increase green signal duration for Webster Avenue
# Increase green signal duration for West 120 Street
# Increase green signal duration for West 120 Street
# Increase green signal duration for West 120 Street
# Increase green signal duration for West 120 Street
# Increase green signal duration for West 120 Street
# Increase green signal duration for West 120 Street
# Increase green signal duration for West 120 Street
# Increase green signal duration for West 120 Street
# Increase green signal duration for West 120 Street
# Decrease green signal duration for West 180 Street
# Decrease green signal duration for West 180 Street
# Decrease green signal duration for West 180 Street
# Decrease green signal duration for West 180 Street
# Decrease green signal duration for West 180 Street
# Decrease green signal duration for West 180 Street
# Decrease green signal duration for West 180 Street
# Decrease green signal duration for West 180 Street
# Decrease green signal duration for West 180 Street
# Decrease green signal duration for West 20 Street
# Decrease green signal duration for West 20 Street
# Decrease green signal duration for West 20 Street
# Increase green signal duration for West 9 Street
# Increase green signal duration for West Drive
# Increase green signal duration for West Drive
# Increase green signal duration for West Drive
# Increase green signal duration for West Drive
# Increase green signal duration for West Drive
# Increase green signal duration for West Drive
# Increase green signal duration for West Drive
# Increase green signal duration for West Drive
# Increase green signal duration for West Drive
# Decrease green signal duration for Whitestone Expressway Sr East
# Decrease green signal duration for Whitestone Expressway Sr East
# Decrease green signal duration for Whitestone Expressway Sr East
# Decrease green signal duration for Whitestone Expressway Sr East
# Decrease green signal duration for Whitestone Expressway Sr East
# Decrease green signal duration for Whitestone Expressway Sr East
# Decrease green signal duration for Whitestone Expressway Sr East
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Williams Avenue
# Decrease green signal duration for Wilson Avenue
# Decrease green signal duration for Wilson Avenue
# Decrease green signal duration for Wilson Avenue
# Decrease green signal duration for YELLOWSTONE BLVD
# Decrease green signal duration for YELLOWSTONE BLVD
# Decrease green signal duration for YELLOWSTONE BLVD
# Decrease green signal duration for YELLOWSTONE BLVD
# Decrease green signal duration for YELLOWSTONE BLVD
# Decrease green signal duration for YELLOWSTONE BLVD
# Decrease green signal duration for YELLOWSTONE BLVD
# Increase green signal duration for YELLOWSTONE BLVD
# Increase green signal duration for YELLOWSTONE BLVD
# Decrease green signal duration for YORK AV

# %%
data_df = data_df.toPandas()

data_df["prev_vol_1"] = data_df["Vol"].shift(1)
data_df["prev_vol_2"] = data_df["Vol"].shift(2)
data_df["prev_vol_3"] = data_df["Vol"].shift(3)

data_df.dropna(inplace=True)

data_df["Vol"] = data_df["Vol"].astype(float)
data_df["prev_vol_1"] = data_df["prev_vol_1"].astype(float)
data_df["prev_vol_2"] = data_df["prev_vol_2"].astype(float)
data_df["prev_vol_3"] = data_df["prev_vol_3"].astype(float)

feature_cols = ["prev_vol_1", "prev_vol_2", "prev_vol_3"]
X = data_df[feature_cols]
y = data_df["Vol"]

scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.fit(X_train, y_train, epochs=25, batch_size=32, validation_data=(X_test, y_test))

loss, mae = model.evaluate(X_test, y_test)
print(f"Mean Absolute Error (MAE): {mae}")

latest_data = data_df.iloc[-3:][feature_cols]
latest_data_normalized = scaler.transform(latest_data)

predicted_volume = model.predict(latest_data_normalized)
print("Predicted Volume:")
print(predicted_volume)
# Out:
# C:\Projects\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 8540.1553 - mae: 35.1692 - val_loss: 2388.1340 - val_mae: 22.8152
# Epoch 2/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 2280.9097 - mae: 18.6952 - val_loss: 2189.9077 - val_mae: 18.2998
# Epoch 3/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 2160.6206 - mae: 18.5869 - val_loss: 2152.7314 - val_mae: 18.1440
# Epoch 4/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 2133.7603 - mae: 18.6076 - val_loss: 2146.6501 - val_mae: 18.6816
# Epoch 5/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 2146.0391 - mae: 18.4387 - val_loss: 2182.9980 - val_mae: 19.9031
# Epoch 6/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 42s 990us/step - loss: 2048.3865 - mae: 18.2599 - val_loss: 2082.4031 - val_mae: 17.6223
# Epoch 7/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 42s 978us/step - loss: 2019.4624 - mae: 18.1238 - val_loss: 2064.3958 - val_mae: 17.3558
# Epoch 8/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 41s 968us/step - loss: 2042.8698 - mae: 17.9022 - val_loss: 2034.8756 - val_mae: 17.5869
# Epoch 9/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1985.8594 - mae: 17.7154 - val_loss: 2041.6318 - val_mae: 17.2625
# Epoch 10/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 41s 950us/step - loss: 1981.2311 - mae: 17.7162 - val_loss: 2079.2156 - val_mae: 18.1658
# Epoch 11/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 54s 1ms/step - loss: 1927.9729 - mae: 17.6787 - val_loss: 1983.7380 - val_mae: 17.0622
# Epoch 12/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 62s 1ms/step - loss: 1958.7909 - mae: 17.5387 - val_loss: 2029.0529 - val_mae: 17.4829
# Epoch 13/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 49s 1ms/step - loss: 1971.3940 - mae: 17.5707 - val_loss: 1940.4712 - val_mae: 17.1248
# Epoch 14/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 1832.2495 - mae: 17.3848 - val_loss: 1936.0052 - val_mae: 17.1939
# Epoch 15/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 1867.6534 - mae: 17.4930 - val_loss: 1983.1244 - val_mae: 18.2111
# Epoch 16/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1989.7968 - mae: 17.5837 - val_loss: 1918.7870 - val_mae: 18.1116
# Epoch 17/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1987.6534 - mae: 17.5647 - val_loss: 1951.3229 - val_mae: 18.2905
# Epoch 18/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1849.9722 - mae: 17.3481 - val_loss: 1915.9772 - val_mae: 17.2549
# Epoch 19/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1906.8278 - mae: 17.4803 - val_loss: 1902.6404 - val_mae: 16.9316
# Epoch 20/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1855.3612 - mae: 17.3064 - val_loss: 1882.4219 - val_mae: 16.6161
# Epoch 21/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1855.7288 - mae: 17.2698 - val_loss: 1924.8491 - val_mae: 16.8783
# Epoch 22/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 1851.6068 - mae: 17.3359 - val_loss: 1851.7216 - val_mae: 16.7620
# Epoch 23/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1874.7584 - mae: 17.2613 - val_loss: 1864.4032 - val_mae: 16.8925
# Epoch 24/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1847.2684 - mae: 17.2092 - val_loss: 1961.3411 - val_mae: 17.9066
# Epoch 25/25
# 42784/42784 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 1922.1512 - mae: 17.3211 - val_loss: 1860.5541 - val_mae: 17.1256
# 10696/10696 ━━━━━━━━━━━━━━━━━━━━ 8s 729us/step - loss: 1752.2117 - mae: 17.1350
# Mean Absolute Error (MAE): 17.12558364868164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Predicted Volume:
# [[110.527466]
#  [126.391785]
#  [126.42843 ]]

# %%
spark.stop()
